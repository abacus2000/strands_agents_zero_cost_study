# %%
from strands import Agent
from strands.models.ollama import OllamaModel
from strands.tool import Tool
import pprint

# Define a simple tool
@Tool(description="Get the current weather for a given city")
def get_weather(city: str) -> str:
    """
    Returns weather information for the specified city.
    
    Args:
        city: The name of the city
    """
    # Simulated weather data
    weather_data = {
        "San Francisco": "Foggy, 60°F",
        "New York": "Sunny, 75°F",
        "Seattle": "Rainy, 55°F",
        "Miami": "Hot and humid, 90°F"
    }
    return weather_data.get(city, f"Weather data not available for {city}")

# Create agent with tool
model = OllamaModel(
    host="http://localhost:11434",
    model_id="llama3.1",
)

weather_agent = Agent(
    model=model,
    tools=[get_weather],
    system_prompt="You are a helpful weather assistant. Use the weather tool to answer questions about weather."
)

print("=" * 60)
print("EXAMPLE 1: Single Tool Call")
print("=" * 60)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from strands import Agent
#       2 from strands.models.ollama import OllamaModel
# ----> 3 from strands.tool import Tool
#       4 import pprint
#       6 # Define a simple tool
#
# ModuleNotFoundError: No module named 'strands.tool'

# %%
agent("hello")
# Out:
# Custom callback triggered
# Yer lookin' fer some help, eh? Well, I be here to lend ye a hand! What be troublein' ye, matey?
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "Yer lookin' fer some help, eh? Well, I be here to lend ye a hand! What be troublein' ye, matey?"}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[14.96027946472168], agent_invocations=[AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='2ae7507b-28bc-4617-9a0d-1eba39a415ee', usage={'inputTokens': 33, 'outputTokens': 30, 'totalTokens': 63})], usage={'inputTokens': 33, 'outputTokens': 30, 'totalTokens': 63})], traces=[<strands.telemetry.metrics.Trace object at 0x7a368990dfd0>], accumulated_usage={'inputTokens': 33, 'outputTokens': 30, 'totalTokens': 63}, accumulated_metrics={'latencyMs': 14925.167686}), state={}, interrupts=None, structured_output=None)
