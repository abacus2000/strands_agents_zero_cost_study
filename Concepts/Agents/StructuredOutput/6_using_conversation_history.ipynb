# %%
from strands import Agent
from pydantic import BaseModel
from typing import Optional
from strands.models.ollama import OllamaModel


model = OllamaModel(
    host="http://localhost:11434",
    model_id="llama3.1",
)

agent = Agent(
    model=model, 
    system_prompt="You are a pithy assistant and you speak very briefly. You speak like Balzac."
)

# %%
# Build up conversation context
agent("What do you know about Paris, France?")
# Out:
# "Ah, the City of Light! Ephemeral fancies dance in its streets, yet eternal grandeur resides within. Montmartre's winding alleys give way to Luxembourg's majestic gardens. The Seine, a serpent of beauty, flows through the heart of Paris."
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '"Ah, the City of Light! Ephemeral fancies dance in its streets, yet eternal grandeur resides within. Montmartre\'s winding alleys give way to Luxembourg\'s majestic gardens. The Seine, a serpent of beauty, flows through the heart of Paris."'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[1.088008165359497], agent_invocations=[AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='6851aa8d-07cf-403d-a395-ae64d8c5b247', usage={'inputTokens': 57, 'outputTokens': 43, 'totalTokens': 100})], usage={'inputTokens': 57, 'outputTokens': 43, 'totalTokens': 100})], traces=[<strands.telemetry.metrics.Trace object at 0x745878dc5010>], accumulated_usage={'inputTokens': 57, 'outputTokens': 43, 'totalTokens': 100}, accumulated_metrics={'latencyMs': 1059.817942}), state={}, interrupts=None, structured_output=None)

# %%
agent("Tell me about the weather there in spring.")
# Out:
# "Spring's whispers turn to torrential rains, then suddenly surrender to golden warmth. Misty mornings yield to sun-kissed afternoons, as if nature itself was torn between seasons."
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '"Spring\'s whispers turn to torrential rains, then suddenly surrender to golden warmth. Misty mornings yield to sun-kissed afternoons, as if nature itself was torn between seasons."'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[1.088008165359497, 0.801140546798706], agent_invocations=[AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='6851aa8d-07cf-403d-a395-ae64d8c5b247', usage={'inputTokens': 57, 'outputTokens': 43, 'totalTokens': 100})], usage={'inputTokens': 57, 'outputTokens': 43, 'totalTokens': 100}), AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='f670139c-ccd4-48f7-8d6a-6500b8ffedf4', usage={'inputTokens': 40, 'outputTokens': 118, 'totalTokens': 158})], usage={'inputTokens': 40, 'outputTokens': 118, 'totalTokens': 158})], traces=[<strands.telemetry.metrics.Trace object at 0x745878dc5010>, <strands.telemetry.metrics.Trace object at 0x745878d89090>], accumulated_usage={'inputTokens': 97, 'outputTokens': 161, 'totalTokens': 258}, accumulated_metrics={'latencyMs': 1836.0542059999998}), state={}, interrupts=None, structured_output=None)

# %%
class CityInfo(BaseModel):
    city: str
    country: str
    population: Optional[int] = None
    climate: str

# Extract structured information from the conversation
result = agent(
    "Extract structured information about Paris from our conversation",
    structured_output_model=CityInfo
)

print(f"City: {result.structured_output.city}")     # "Paris"
print(f"Country: {result.structured_output.country}") # "France"
# Out:
# Tool #1: CityInfo
# City: Paris
# Country: France
